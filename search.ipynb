# %%
import pandas as pd
import re

# %%
from google.colab import drive 
drive.mount('/content/gdrive')

search1 = pd.read_csv('gdrive/My Drive/lpoint2.csv', engine='python', encoding='cp949') 
master_brand = pd.read_csv('gdrive/My Drive/master_brand.csv', engine='python', encoding='cp949')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
search1
# Client ID, Session ID를 포함한 검색어의 data table
# Out:
#          CLNT_ID   SESS_ID      KWD_NM  SEARCH_CNT
# 0        5607714   7112876    빌리프 아이크림           6
# 1        5607714   4090791   프리메라 마스크팩           3
# 2        5607714   4090791       여성청결제           1
# 3        5612428   1876482        명품가방           1
# 4        5612428    658123   콩순이 아이스크림           1
# 5        5612428   1876482  블루독 티셔츠 남아           1
# 6        5612471   8539312       쉬폰원피스           1
# 7        5612471   8539312  여성 쉬폰 블라우스           1
# 8        5613055   8510027      임산부 팬티           2
# 9        5613055   8510027     임산부 원피스           1
# 10       5609603  10483281       베베드피노          27
# 11       5609603  10483281         쁘띠뮤           6
# 12       5609603  10483281   베베드피노 티셔츠           2
# 13       5609763   6286724   남성 반팔 티셔츠           4
# 14       5609800   7380789    메트로시티 지갑           1
# 15       5609800  10249029   닥스 양말선물세트           1
# 16       5609800   7380789       크로커다일           2
# 17       5609800   7380789    크로커다일레이디           2
# 18       5609800   5655924       앤듀 셔츠           1
# 19       5609800  10249029         옷커버           1
# 20       5609800   5715066       헤지스남성           1
# 21       5609800   5396908      올리비안로렌           1
# 22       5609800   7852075      올즙 건강즙           1
# 23       5609800   4844925         헤지스           1
# 24       5609800   5715066    헤지스남성티셔츠           2
# 25       5609800   5396908     바이네르여성화           1
# 26       5609800   7852075      올리비안로렌           1
# 27       5609800   7852075     나이스클랍팬츠           1
# 28       5609800   7852075        닥스지갑           1
# 29       5609800   7852075   올리비안로렌 바지           1
# ...          ...       ...         ...         ...
# 2884913  6387880   3844161      진주 원피스           4
# 2884914  6387880   3547761     데상트 반바지           2
# 2884915  6387880   3547761        맥 대즐           5
# 2884916  6388296   2914718     엠폴햄 티셔츠           1
# 2884917  6388296   2914718        폴햄셔츠           2
# 2884918  6388296   2914718         펠틱스           1
# 2884919  6388296   2914718          폴햄           1
# 2884920  6388327   8729180        에티튜드           1
# 2884921  6388327   8729180   에티튜드 세탁세제           1
# 2884922  6382387   7858219        보드게임           3
# 2884923  6389841   1588301        들깨가루           1
# 2884924  6390176   3945036       미디스커트           1
# 2884925  6390246      8296       타미진여성           1
# 2884926  6390246      8296      루즈핏 코트           1
# 2884927  6390246      8296     타미힐피거여성           1
# 2884928  6390246      8296        아나이스           1
# 2884929  6390246      8296      루즈핏 셔츠           1
# 2884930  6390246      8296     루즈핏 티셔츠           1
# 2884931  6390246      8296         톰보이           1
# 2884932  6385382   9274001   이니스프리 클렌징           1
# 2884933  6385382   9274001        마녀공장           1
# 2884934  6385382   9274001        모델링팩           1
# 2884935  6385382   9274001     dr.jart           1
# 2884936  6385382   9274001         시드물           1
# 2884937  6391796   1521999       여성슬립온           5
# 2884938  6391796   1822515         일자핏           1
# 2884939  6391796   1822515      화이트티셔츠           1
# 2884940  6391796    764020          양말           6
# 2884941  6391796   1822515          어항           2
# 2884942  6391931   1568433      블랙야크키즈           1
#
# [2884943 rows x 4 columns]

# %%
# Keyword name에서 unique한 것만 추출

KWD_unique = list(set(search1["KWD_NM"]))
len(KWD_unique)
# Out:
# 81539

# %%
original_master_brand = master_brand[:]
original_master_brand
# 브랜드명과 분류명(대, 중, 소)을 포함한 data table
# Out:
#         Unnamed: 0    PD_C                                              PD_NM  \
# 0                0       1                     PN클래드IH압력솥 2인용+사은품 실리콘그립손잡이 증정
# 1                1       2                                스톤헨지 레이어드목걸이 SC0084
# 2                2       3                  [XEEON] 에어렉스 스포츠 골프화 실리콘 신발끈 - 그린
# 3                3       4                  [XEEON] 에어렉스 스포츠 골프화 실리콘 구두끈 - 블랙
# 4                4       5  [XEEON] 에어렉스 골프화 실리콘신발끈 + 실리콘구두끈 세트 - 구두끈_브라운 ...
# 5                5       6             2014 F/W 스트랩 SE4A5A06 (BLK) - 블랙 / 235
# 6                6       7  크록스키즈 크록밴드 클로그(204537外) 샌들/아쿠아슈즈 택일 - 11990-42...
# 7                7       8                   CASAON 엘리트 LX200S 메쉬 라텍스 의자 - 블루
# 8                8       9                   CASAON 엘리트 LX110B 메쉬 라텍스 의자 - 블루
# 9                9      10                     브론즈 즈로즈 (2매입) 남성팬티 남성속옷 - 100호
# 10              10      11                                    걸음마학습기(한영버전)_핑크
# 11              11      12  아쿠윈 울트라코팅 수모 (Ultra Coating Swim Cap) 수영모자 수모 ...
# 12              12      13     아쿠윈 Vfinger 일반용 수영모자 수모 실리콘 고무 수모 수영용품 - Black
# 13              13      14                    키친아트 웰빙 스텐 사각 김치통 3종 세트 (대,중,소)
# 14              14      15                          프리미엄 엠보싱리필형[20팩] 안심 아기물티슈
# 15              15      16                              프리미엄 플레인캡형[20팩] 아기물티슈
# 16              16      17                             베이직 엠보싱캡형[20팩]안심 아기물티슈
# 17              17      18                             베이직 플레인캡형[20팩]안심 아기물티슈
# 18              18      19                            베이직 플레인리필형[20팩]안심 아기물티슈
# 19              19      20                            오리지널 엠보싱캡형[20팩]안심 아기물티슈
# 20              20      21   CASAONNeo클래식 서랍형 도장 침대(양모 라텍스 독립스프링 매트리스-퀸) - 월넛
# 21              21      22              CASAONNeo클래식 서랍형 도장 침대(매트제외-퀸) - 아이보리
# 22              22      23                             [아이조아] 쉿 개조심 쉿개조심 보드게임
# 23              23      24                           오리지널 엠보싱리필형[20팩]안심 아기물티슈
# 24              24      25                  코엔자임큐텐 2입 세트 (60캡슐*2) - 코엔자임큐텐 세트
# 25              25      26     아쿠윈 CR39M SM/SM (미러코팅) 여성용 수경,물안경,수영용품 - SM/SM
# 26              26      27                           오리지널 플레인리필형[20팩]안심 아기물티슈
# 27              27      28              여성 펌프스 J1209V CK-101 흑색 (7CM) - 225지갑
# 28              28      29     [롯데백화점] 디자인나이프 大 접시 (평접시 27cm) - 4. 벽난로(72626)
# 29              29      30    [롯데백화점] 디자인나이프 中 접시 (샐러드 접시 21cm - 2. 노아(72643)
# ...            ...     ...                                                ...
# 847622      847622  847623                              악티펌 리얼 리프팅 셀 에센스_30ml
# 847623      847623  847624                               아쿠아 에센셜 블루 EDT 100ml
# 847624      847624  847625                               악티펌 리얼 리프팅 에멀젼_130ml
# 847625      847625  847626                   서클 나염 차렵이불세트 퀸 (베개2+차렵이불) - 인디핑크
# 847626      847626  847627                                악티펌 리얼 리프팅 토너_130ml
# 847627      847627  847628       [냉동] CJ 비비고 한입떡갈비 282g×2번들×2개 (총 4개) - 합입떡갈비
# 847628      847628  847629                      [냉동] CJ 비비고 한입떡갈비 282g×2개(번들)
# 847629      847629  847630                              [냉동] CJ 백설군만두 400g×6개
# 847630      847630  847631  [케즈/keds] WF34000 (White) Champion Core CVO 남여...
# 847631      847631  847632                                        키친플라워 잼팟 9L
# 847632      847632  847633                      트라이디어 갤럭시노트엣지 O통케 케이스 - 스카이블루
# 847633      847633  847634                호텔콜렉션 80수 양면 헝가리산 거위털 세트 킹(이불+침구세트)
# 847634      847634  847635                     호텔콜렉션 80수 양면 디럭스 세트 킹(이불+침구세트)
# 847635      847635  847636                     호텔콜렉션 80수 양면 덕다운 세트 퀸(이불+침구세트)
# 847636      847636  847637                 호텔콜렉션 80수 양면 사계절 오리털 세트 퀸(이불+침구세트)
# 847637      847637  847638                     호텔콜렉션 80수 양면 디럭스 세트 퀸(이불+침구세트)
# 847638      847638  847639              (6종)전통 입체인형 볼펜세트 (신)/어학연수홈스테이외국인선물로추천
# 847639      847639  847640         소다 남성 스니커즈 AGM350 네이비,카멜,다크브라운 - 265 / 네이비
# 847640      847640  847641                                     제니 소파베드C1 - 블랙
# 847641      847641  847642              모던걸 여삼각(2매입) 아동속옷 기획상품_(65~90호) - 70호
# 847642      847642  847643                          K2152SC 내열유리 소스병 195ml 2P
# 847643      847643  847644                                      [레고] 8293파워펑션
# 847644      847644  847645                                        데니 5단서랍장 오크
# 847645      847645  847646                                       데니 와이드서랍장 오크
# 847646      847646  847647                                       데니 5단서랍장 메이플
# 847647      847647  847648                                     데니 와이드 서랍장 메이플
# 847648      847648  847649                             쿠키앤크림_블랙쿠키 5단 책장 (구)웅스
# 847649      847649  847650         아쿠윈 SP 태극기 수모, Taegeukgi 수영모자 수영용품 - White
# 847650      847650  847651               아쿠윈 BLOCK 성인 일반용 수영모자 수모 수영용품 - Blue
# 847651      847651  847652  아쿠윈 WP 아쿠아위너 수모, AQUA WINNER  ★특별할인 50% 대박이벤트 ...
#
#         PD_BRA_NM   CLAC1_NM   CLAC2_NM    CLAC3_NM
# 0              풍년    식기/조리기구       조리기구         압력솥
# 1       스톤헨지(주얼리)       패션잡화         보석         목걸이
# 2           XEEON   구기/필드스포츠         골프      골프연습장비
# 3           XEEON   구기/필드스포츠         골프      골프연습장비
# 4           XEEON   구기/필드스포츠         골프      골프연습장비
# 5          게스(구두)       패션잡화        여성화       여성펌프스
# 6             크록스      시즌스포츠     수영/물놀이       아쿠아슈즈
# 7         까사미아까사온         가구       거실가구     스툴/리빙의자
# 8         까사미아까사온         가구       거실가구     스툴/리빙의자
# 9            쿠스쿠스  속옷/양말/홈웨어       남성속옷        남성팬티
# 10            브이텍    출산/육아용품     유아발육용품  바운서/쏘서/보행기
# 11            아쿠윈      시즌스포츠     수영/물놀이        수영모자
# 12            아쿠윈      시즌스포츠     수영/물놀이        수영모자
# 13           키친아트    식기/조리기구    밀폐/보관용기    반찬통/밀폐용기
# 14         네츄럴오가닉    출산/육아용품     유아위생용품      유아용물티슈
# 15         네츄럴오가닉    출산/육아용품     유아위생용품      유아용물티슈
# 16         네츄럴오가닉    출산/육아용품     유아위생용품      유아용물티슈
# 17         네츄럴오가닉    출산/육아용품     유아위생용품      유아용물티슈
# 18         네츄럴오가닉    출산/육아용품     유아위생용품      유아용물티슈
# 19         네츄럴오가닉    출산/육아용품     유아위생용품      유아용물티슈
# 20        까사미아까사온         가구       침실가구      침실가구세트
# 21        까사미아까사온         가구       침실가구      침실가구세트
# 22           아이조아         완구       교육완구        보드게임
# 23         네츄럴오가닉    출산/육아용품     유아위생용품      유아용물티슈
# 24           세노비스       건강식품        영양제       기타영양제
# 25            아쿠윈      시즌스포츠     수영/물놀이         물안경
# 26         네츄럴오가닉    출산/육아용품     유아위생용품      유아용물티슈
# 27        탠디(여성화)       패션잡화        여성화       여성펌프스
# 28        빌레로이앤보흐    식기/조리기구      그릇/식기          접시
# 29        빌레로이앤보흐    식기/조리기구      그릇/식기          접시
# ...           ...        ...        ...         ...
# 847622        닥터지   화장품/뷰티케어       스킨케어      에센스/세럼
# 847623       페라가모   화장품/뷰티케어         향수        남성향수
# 847624        닥터지   화장품/뷰티케어       스킨케어      에멀젼/로션
# 847625       주호데코      침구/수예       성인침구      성인침구세트
# 847626        닥터지   화장품/뷰티케어       스킨케어         미스트
# 847627    씨제이제일제당       냉동식품      냉동간편식        냉동부침
# 847628    씨제이제일제당       냉동식품      냉동간편식        냉동부침
# 847629    씨제이제일제당       냉동식품      냉동간편식        냉동만두
# 847630        스닉솔      유아동의류       유아동화     유아동스니커즈
# 847631      키친플라워    식기/조리기구       조리기구           솥
# 847632      트라이디어        모바일    모바일액세서리    케이스/보호필름
# 847633      헬렌스타인      침구/수예       성인침구      성인침구세트
# 847634      헬렌스타인      침구/수예       성인침구      성인침구세트
# 847635      헬렌스타인      침구/수예       성인침구      성인침구세트
# 847636      헬렌스타인      침구/수예       성인침구      성인침구세트
# 847637      헬렌스타인      침구/수예       성인침구      성인침구세트
# 847638       박씨상방       패션잡화     패션액세서리    전통/종교장신구
# 847639    소다(남성화)       패션잡화        남성화      남성컴포트화
# 847640      베스트리빙         가구       거실가구          소파
# 847641       첨이첨이      유아동의류      유아동속옷       유아동팬티
# 847642       로소리갈    식기/조리기구    밀폐/보관용기    반찬통/밀폐용기
# 847643         레고         완구       교육완구          레고
# 847644       데코라인         가구       수납가구      선반장/행거
# 847645       데코라인         가구       수납가구      선반장/행거
# 847646       데코라인         가구       수납가구      선반장/행거
# 847647       데코라인         가구       수납가구      선반장/행거
# 847648        채우리         가구  사무용/학생용가구          책장
# 847649        아쿠윈      시즌스포츠     수영/물놀이        수영모자
# 847650        아쿠윈      시즌스포츠     수영/물놀이        수영모자
# 847651        아쿠윈      시즌스포츠     수영/물놀이        수영모자
#
# [847652 rows x 7 columns]

# %%
# brand name 전처리 ("[]", ".", "(주)" 등 제거)

myBRD_NM = []
p1 = re.compile("[(].*[)]")
p2 = re.compile("\W")

for brd_nm in master_brand["PD_BRA_NM"]:
  b1 = p1.sub("", brd_nm)
  b2 = p2.sub("", b1)
  myBRD_NM.append(b2)
  
master_brand["PD_BRA_NM"] = myBRD_NM
master_brand
# Out:
#         Unnamed: 0    PD_C                                              PD_NM  \
# 0                0       1                     PN클래드IH압력솥 2인용+사은품 실리콘그립손잡이 증정
# 1                1       2                                스톤헨지 레이어드목걸이 SC0084
# 2                2       3                  [XEEON] 에어렉스 스포츠 골프화 실리콘 신발끈 - 그린
# 3                3       4                  [XEEON] 에어렉스 스포츠 골프화 실리콘 구두끈 - 블랙
# 4                4       5  [XEEON] 에어렉스 골프화 실리콘신발끈 + 실리콘구두끈 세트 - 구두끈_브라운 ...
# 5                5       6             2014 F/W 스트랩 SE4A5A06 (BLK) - 블랙 / 235
# 6                6       7  크록스키즈 크록밴드 클로그(204537外) 샌들/아쿠아슈즈 택일 - 11990-42...
# 7                7       8                   CASAON 엘리트 LX200S 메쉬 라텍스 의자 - 블루
# 8                8       9                   CASAON 엘리트 LX110B 메쉬 라텍스 의자 - 블루
# 9                9      10                     브론즈 즈로즈 (2매입) 남성팬티 남성속옷 - 100호
# 10              10      11                                    걸음마학습기(한영버전)_핑크
# 11              11      12  아쿠윈 울트라코팅 수모 (Ultra Coating Swim Cap) 수영모자 수모 ...
# 12              12      13     아쿠윈 Vfinger 일반용 수영모자 수모 실리콘 고무 수모 수영용품 - Black
# 13              13      14                    키친아트 웰빙 스텐 사각 김치통 3종 세트 (대,중,소)
# 14              14      15                          프리미엄 엠보싱리필형[20팩] 안심 아기물티슈
# 15              15      16                              프리미엄 플레인캡형[20팩] 아기물티슈
# 16              16      17                             베이직 엠보싱캡형[20팩]안심 아기물티슈
# 17              17      18                             베이직 플레인캡형[20팩]안심 아기물티슈
# 18              18      19                            베이직 플레인리필형[20팩]안심 아기물티슈
# 19              19      20                            오리지널 엠보싱캡형[20팩]안심 아기물티슈
# 20              20      21   CASAONNeo클래식 서랍형 도장 침대(양모 라텍스 독립스프링 매트리스-퀸) - 월넛
# 21              21      22              CASAONNeo클래식 서랍형 도장 침대(매트제외-퀸) - 아이보리
# 22              22      23                             [아이조아] 쉿 개조심 쉿개조심 보드게임
# 23              23      24                           오리지널 엠보싱리필형[20팩]안심 아기물티슈
# 24              24      25                  코엔자임큐텐 2입 세트 (60캡슐*2) - 코엔자임큐텐 세트
# 25              25      26     아쿠윈 CR39M SM/SM (미러코팅) 여성용 수경,물안경,수영용품 - SM/SM
# 26              26      27                           오리지널 플레인리필형[20팩]안심 아기물티슈
# 27              27      28              여성 펌프스 J1209V CK-101 흑색 (7CM) - 225지갑
# 28              28      29     [롯데백화점] 디자인나이프 大 접시 (평접시 27cm) - 4. 벽난로(72626)
# 29              29      30    [롯데백화점] 디자인나이프 中 접시 (샐러드 접시 21cm - 2. 노아(72643)
# ...            ...     ...                                                ...
# 847622      847622  847623                              악티펌 리얼 리프팅 셀 에센스_30ml
# 847623      847623  847624                               아쿠아 에센셜 블루 EDT 100ml
# 847624      847624  847625                               악티펌 리얼 리프팅 에멀젼_130ml
# 847625      847625  847626                   서클 나염 차렵이불세트 퀸 (베개2+차렵이불) - 인디핑크
# 847626      847626  847627                                악티펌 리얼 리프팅 토너_130ml
# 847627      847627  847628       [냉동] CJ 비비고 한입떡갈비 282g×2번들×2개 (총 4개) - 합입떡갈비
# 847628      847628  847629                      [냉동] CJ 비비고 한입떡갈비 282g×2개(번들)
# 847629      847629  847630                              [냉동] CJ 백설군만두 400g×6개
# 847630      847630  847631  [케즈/keds] WF34000 (White) Champion Core CVO 남여...
# 847631      847631  847632                                        키친플라워 잼팟 9L
# 847632      847632  847633                      트라이디어 갤럭시노트엣지 O통케 케이스 - 스카이블루
# 847633      847633  847634                호텔콜렉션 80수 양면 헝가리산 거위털 세트 킹(이불+침구세트)
# 847634      847634  847635                     호텔콜렉션 80수 양면 디럭스 세트 킹(이불+침구세트)
# 847635      847635  847636                     호텔콜렉션 80수 양면 덕다운 세트 퀸(이불+침구세트)
# 847636      847636  847637                 호텔콜렉션 80수 양면 사계절 오리털 세트 퀸(이불+침구세트)
# 847637      847637  847638                     호텔콜렉션 80수 양면 디럭스 세트 퀸(이불+침구세트)
# 847638      847638  847639              (6종)전통 입체인형 볼펜세트 (신)/어학연수홈스테이외국인선물로추천
# 847639      847639  847640         소다 남성 스니커즈 AGM350 네이비,카멜,다크브라운 - 265 / 네이비
# 847640      847640  847641                                     제니 소파베드C1 - 블랙
# 847641      847641  847642              모던걸 여삼각(2매입) 아동속옷 기획상품_(65~90호) - 70호
# 847642      847642  847643                          K2152SC 내열유리 소스병 195ml 2P
# 847643      847643  847644                                      [레고] 8293파워펑션
# 847644      847644  847645                                        데니 5단서랍장 오크
# 847645      847645  847646                                       데니 와이드서랍장 오크
# 847646      847646  847647                                       데니 5단서랍장 메이플
# 847647      847647  847648                                     데니 와이드 서랍장 메이플
# 847648      847648  847649                             쿠키앤크림_블랙쿠키 5단 책장 (구)웅스
# 847649      847649  847650         아쿠윈 SP 태극기 수모, Taegeukgi 수영모자 수영용품 - White
# 847650      847650  847651               아쿠윈 BLOCK 성인 일반용 수영모자 수모 수영용품 - Blue
# 847651      847651  847652  아쿠윈 WP 아쿠아위너 수모, AQUA WINNER  ★특별할인 50% 대박이벤트 ...
#
#        PD_BRA_NM   CLAC1_NM   CLAC2_NM    CLAC3_NM
# 0             풍년    식기/조리기구       조리기구         압력솥
# 1           스톤헨지       패션잡화         보석         목걸이
# 2          XEEON   구기/필드스포츠         골프      골프연습장비
# 3          XEEON   구기/필드스포츠         골프      골프연습장비
# 4          XEEON   구기/필드스포츠         골프      골프연습장비
# 5             게스       패션잡화        여성화       여성펌프스
# 6            크록스      시즌스포츠     수영/물놀이       아쿠아슈즈
# 7        까사미아까사온         가구       거실가구     스툴/리빙의자
# 8        까사미아까사온         가구       거실가구     스툴/리빙의자
# 9           쿠스쿠스  속옷/양말/홈웨어       남성속옷        남성팬티
# 10           브이텍    출산/육아용품     유아발육용품  바운서/쏘서/보행기
# 11           아쿠윈      시즌스포츠     수영/물놀이        수영모자
# 12           아쿠윈      시즌스포츠     수영/물놀이        수영모자
# 13          키친아트    식기/조리기구    밀폐/보관용기    반찬통/밀폐용기
# 14        네츄럴오가닉    출산/육아용품     유아위생용품      유아용물티슈
# 15        네츄럴오가닉    출산/육아용품     유아위생용품      유아용물티슈
# 16        네츄럴오가닉    출산/육아용품     유아위생용품      유아용물티슈
# 17        네츄럴오가닉    출산/육아용품     유아위생용품      유아용물티슈
# 18        네츄럴오가닉    출산/육아용품     유아위생용품      유아용물티슈
# 19        네츄럴오가닉    출산/육아용품     유아위생용품      유아용물티슈
# 20       까사미아까사온         가구       침실가구      침실가구세트
# 21       까사미아까사온         가구       침실가구      침실가구세트
# 22          아이조아         완구       교육완구        보드게임
# 23        네츄럴오가닉    출산/육아용품     유아위생용품      유아용물티슈
# 24          세노비스       건강식품        영양제       기타영양제
# 25           아쿠윈      시즌스포츠     수영/물놀이         물안경
# 26        네츄럴오가닉    출산/육아용품     유아위생용품      유아용물티슈
# 27            탠디       패션잡화        여성화       여성펌프스
# 28       빌레로이앤보흐    식기/조리기구      그릇/식기          접시
# 29       빌레로이앤보흐    식기/조리기구      그릇/식기          접시
# ...          ...        ...        ...         ...
# 847622       닥터지   화장품/뷰티케어       스킨케어      에센스/세럼
# 847623      페라가모   화장품/뷰티케어         향수        남성향수
# 847624       닥터지   화장품/뷰티케어       스킨케어      에멀젼/로션
# 847625      주호데코      침구/수예       성인침구      성인침구세트
# 847626       닥터지   화장품/뷰티케어       스킨케어         미스트
# 847627   씨제이제일제당       냉동식품      냉동간편식        냉동부침
# 847628   씨제이제일제당       냉동식품      냉동간편식        냉동부침
# 847629   씨제이제일제당       냉동식품      냉동간편식        냉동만두
# 847630       스닉솔      유아동의류       유아동화     유아동스니커즈
# 847631     키친플라워    식기/조리기구       조리기구           솥
# 847632     트라이디어        모바일    모바일액세서리    케이스/보호필름
# 847633     헬렌스타인      침구/수예       성인침구      성인침구세트
# 847634     헬렌스타인      침구/수예       성인침구      성인침구세트
# 847635     헬렌스타인      침구/수예       성인침구      성인침구세트
# 847636     헬렌스타인      침구/수예       성인침구      성인침구세트
# 847637     헬렌스타인      침구/수예       성인침구      성인침구세트
# 847638      박씨상방       패션잡화     패션액세서리    전통/종교장신구
# 847639        소다       패션잡화        남성화      남성컴포트화
# 847640     베스트리빙         가구       거실가구          소파
# 847641      첨이첨이      유아동의류      유아동속옷       유아동팬티
# 847642      로소리갈    식기/조리기구    밀폐/보관용기    반찬통/밀폐용기
# 847643        레고         완구       교육완구          레고
# 847644      데코라인         가구       수납가구      선반장/행거
# 847645      데코라인         가구       수납가구      선반장/행거
# 847646      데코라인         가구       수납가구      선반장/행거
# 847647      데코라인         가구       수납가구      선반장/행거
# 847648       채우리         가구  사무용/학생용가구          책장
# 847649       아쿠윈      시즌스포츠     수영/물놀이        수영모자
# 847650       아쿠윈      시즌스포츠     수영/물놀이        수영모자
# 847651       아쿠윈      시즌스포츠     수영/물놀이        수영모자
#
# [847652 rows x 7 columns]

# %%
# brand name에서 unique한 것만 추출

BRD_unique = list(set(master_brand["PD_BRA_NM"]))
len(BRD_unique)
# Out:
# 12650

# %%
# 분류명에서 unique한 것만 추출 (2개 이상이 묶여있는 것 분리)

for clac_nm in set(master_brand["CLAC1_NM"]):
  if "/" in clac_nm: print(clac_nm)
# Out:
# 식기/조리기구
# 출산/육아용품
# 냉장/세탁가전
# 문구/사무용품
# 원예/애완
# 생활/주방가전
# 헬스/피트니스
# 청소/세탁/욕실용품
# 세제/위생
# 속옷/양말/홈웨어
# 화장품/뷰티케어
# 구기/필드스포츠
# 인테리어/조명
# 아웃도어/레저
# 침구/수예
# 영상/음향가전

# %%
CLAC1, CLAC2, CLAC3 = [], [], []

for clac1 in set(master_brand["CLAC1_NM"]):
  CLAC1 += clac1.split("/")
  
for clac2 in set(master_brand["CLAC2_NM"]):
  CLAC2 += clac2.split("/")

for clac3 in set(master_brand["CLAC3_NM"]):
  CLAC3 += clac3.split("/")

CLAC1_unique = list(set(CLAC1))
CLAC2_unique = list(set(CLAC2))
CLAC3_unique = list(set(CLAC3))

# %% [markdown]
# ### search1의 Keyword Name에서 Brand Name 분리

# %%
# 대소문자 통일

for (i, kwd_nm) in enumerate(KWD_unique):
  KWD_unique[i] = kwd_nm.upper()

for (i, brd_nm) in enumerate(BRD_unique):
  BRD_unique[i] = brd_nm.upper()

# %%
# brand name이 분류명과 같은 것 제거

for brd_nm in BRD_unique:
  if brd_nm in (CLAC1_unique + CLAC2_unique + CLAC3_unique):
    BRD_unique.remove(brd_nm)
    print(brd_nm)
# Out:
# 보드게임
# 랩
# 커버
# 원피스
# 칼
# 볼
# 탑
# 캐리어
# 살구
# 고양이사료
# 클립
# 풋케어
# 레고
# 포크
# 아이젠
# 립밤

# %%
BRD_unique.remove('여성')
BRD_unique.remove('크로스')

# %%
### search1의 Keyword Name에서 Brand Name 분리

myBRD, myKWD = [], []
p = re.compile('(\w*) .*')

for kwd in KWD_unique:
  
  if kwd in BRD_unique: brd = kwd
  elif p.match(kwd):
    g1 = p.match(kwd).group(1)
    brd = g1 if g1 in BRD_unique else ""
  else:
    brd = ""
    for brd_nm in BRD_unique:
      if kwd.find(brd_nm) == 0 and len(brd_nm) > max(1, len(brd)):
        brd = brd_nm
      
  myBRD.append(brd)
  myKWD.append(kwd.replace(brd, "").lstrip())   # brand name 떼고 왼쪽 공백 제거
# Out:
# 142.3845985969997

# %%
mysearch1 = pd.DataFrame({'KWD':list(KWD_unique), 'myBRD':myBRD, 'myKWD':myKWD})
mysearch1
# Out:
#                  KWD    myBRD          myKWD
# 0              린넨스커트                   린넨스커트
# 1               쿠키세븐     쿠키세븐
# 2                배불리                     배불리
# 3               유리꽃병                    유리꽃병
# 4           디스커버리 힙색    디스커버리             힙색
# 5            락피쉬젤리슈즈      락피쉬           젤리슈즈
# 6           타미힐피거 카라    타미힐피거             카라
# 7        아디다스 운동복 여성     아디다스         운동복 여성
# 8             튜닉블라우스                  튜닉블라우스
# 9              탑걸 자켓       탑걸             자켓
# 10         아레나 반신 여성      아레나          반신 여성
# 11         M71MQ563Z               M71MQ563Z
# 12              면 잠옷                    면 잠옷
# 13             인디안자켓      인디안             자켓
# 14              프렌치불     프렌치불
# 15             밴딩원피스                   밴딩원피스
# 16            남자 넥타이                  남자 넥타이
# 17           여자 카드지갑                 여자 카드지갑
# 18             스노우메리    스노우메리
# 19             유리반찬통                   유리반찬통
# 20             미세스지니    미세스지니
# 21            르카프티셔츠                  르카프티셔츠
# 22                일본                      일본
# 23             바디파우더                   바디파우더
# 24               수면팩                     수면팩
# 25        와이케이편집샵원피스  와이케이편집샵            원피스
# 26           나이키 270      나이키            270
# 27              트레몰로     트레몰로
# 28              룻데닷컴                    룻데닷컴
# 29         썰스데이 아일랜드               썰스데이 아일랜드
# ...              ...      ...            ...
# 81509          설화수쿠션      설화수             쿠션
# 81510       아레나 미러수경      아레나           미러수경
# 81511          팬티 세트                   팬티 세트
# 81512          애플라인드    애플라인드
# 81513         건조기거치대                  건조기거치대
# 81514      레노마 골프 여성      레노마          골프 여성
# 81515            메트로                     메트로
# 81516         골프바람막이                  골프바람막이
# 81517    갤럭시노트8 강화유리             갤럭시노트8 강화유리
# 81518      HSSH7C708               HSSH7C708
# 81519        크록스아동장화      크록스           아동장화
# 81520         르꼬끄골프백    르꼬끄골프              백
# 81521  CRP-FHR0610FD           CRP-FHR0610FD
# 81522            쓰리심                     쓰리심
# 81523      여성 로퍼 3CM               여성 로퍼 3CM
# 81524           한샘주방       한샘             주방
# 81525            270                     270
# 81526    빈폴남성 반팔 티셔츠             빈폴남성 반팔 티셔츠
# 81527            리멘트      리멘트
# 81528         MIUMIU                  MIUMIU
# 81529        세라 크로스백       세라           크로스백
# 81530        지지피엑스바지    지지피엑스             바지
# 81531            털모자                     털모자
# 81532        키플링 시티팩      키플링            시티팩
# 81533            모델로                     모델로
# 81534        이오시카제모기     이오시카            제모기
# 81535       레스포색 토트백     레스포색            토트백
# 81536           프라이멀                    프라이멀
# 81537       FCMM 후리스                FCMM 후리스
# 81538            스파클      스파클
#
# [81539 rows x 3 columns]

# %% [markdown]
# ## search1을 상품군별로 분류

# %%
mysearch1_1 = mysearch1[mysearch1["myKWD"] != ""]    # keyword = brand name 인 것 제외
len(mysearch1_1)
# Out:
# 76010

# %% [markdown]
# ### 1차 분류: keyword가 CLAC_NM를 포함하는 것 분류

# %%
CLAC3_unique.remove("유아")

# %%
myCLAC1, myCLAC2, myCLAC3 = [], [], []

for kwd in mysearch1_1["myKWD"]:
  c1, c2, c3 = "", "", ""
  
  if kwd in CLAC2_unique: c2 = kwd
  elif kwd in CLAC3_unique: c3 = kwd
  elif kwd in CLAC1_unique: c1 = kwd

  else:
    for clac2 in CLAC2_unique:
      if clac2 in kwd: c2 = clac2
      
    if c1 == "" and c2 == "" and c3 == "":
      for clac3 in CLAC3_unique:
        if clac3 in kwd and len(clac3) > 1: c3 = clac3
      
      if c3 == "":
        for clac1 in CLAC1_unique:
          if clac1 in kwd: c1 = clac1
            
  myCLAC1.append(c1)
  myCLAC2.append(c2)
  myCLAC3.append(c3)

# %%
mysearch1_2 = pd.DataFrame({'KWD':mysearch1_1["KWD"], 'myBRD':mysearch1_1["myBRD"], 'myKWD':mysearch1_1["myKWD"],
                            'myCLAC1_NM':myCLAC1, 'myCLAC2_NM':myCLAC2, 'myCLAC3_NM':myCLAC3})
mysearch1_2 = mysearch1_2[['KWD', 'myBRD', 'myKWD', 'myCLAC1_NM', 'myCLAC2_NM', 'myCLAC3_NM']]
mysearch1_2
# Out:
#                  KWD    myBRD          myKWD myCLAC1_NM myCLAC2_NM myCLAC3_NM
# 0              린넨스커트                   린넨스커트                              스커트
# 2                배불리                     배불리
# 3               유리꽃병                    유리꽃병
# 4           디스커버리 힙색    디스커버리             힙색                               힙색
# 5            락피쉬젤리슈즈      락피쉬           젤리슈즈                               슈즈
# 6           타미힐피거 카라    타미힐피거             카라
# 7        아디다스 운동복 여성     아디다스         운동복 여성
# 8             튜닉블라우스                  튜닉블라우스
# 9              탑걸 자켓       탑걸             자켓
# 10         아레나 반신 여성      아레나          반신 여성
# 11         M71MQ563Z               M71MQ563Z
# 12              면 잠옷                    면 잠옷
# 13             인디안자켓      인디안             자켓
# 15             밴딩원피스                   밴딩원피스                              원피스
# 16            남자 넥타이                  남자 넥타이
# 17           여자 카드지갑                 여자 카드지갑
# 19             유리반찬통                   유리반찬통                              반찬통
# 21            르카프티셔츠                  르카프티셔츠
# 22                일본                      일본
# 23             바디파우더                   바디파우더                              파우더
# 24               수면팩                     수면팩
# 25        와이케이편집샵원피스  와이케이편집샵            원피스                              원피스
# 26           나이키 270      나이키            270
# 28              룻데닷컴                    룻데닷컴
# 29         썰스데이 아일랜드               썰스데이 아일랜드
# 30            롱트렌치코트                  롱트렌치코트
# 31         레노마 여성수영복      레노마          여성수영복                            여성수영복
# 32               점퍼루                     점퍼루
# 33             IWC시계                   IWC시계                    시계
# 34                치실                      치실
# ...              ...      ...            ...        ...        ...        ...
# 81506         WAAC골프                  WAAC골프                    골프
# 81507         초고속블렌더                  초고속블렌더
# 81508        버켄스탁밀라노     버켄스탁            밀라노
# 81509          설화수쿠션      설화수             쿠션                               쿠션
# 81510       아레나 미러수경      아레나           미러수경
# 81511          팬티 세트                   팬티 세트
# 81513         건조기거치대                  건조기거치대                              건조기
# 81514      레노마 골프 여성      레노마          골프 여성                    골프
# 81515            메트로                     메트로
# 81516         골프바람막이                  골프바람막이                    골프
# 81517    갤럭시노트8 강화유리             갤럭시노트8 강화유리
# 81518      HSSH7C708               HSSH7C708
# 81519        크록스아동장화      크록스           아동장화
# 81520         르꼬끄골프백    르꼬끄골프              백
# 81521  CRP-FHR0610FD           CRP-FHR0610FD
# 81522            쓰리심                     쓰리심
# 81523      여성 로퍼 3CM               여성 로퍼 3CM
# 81524           한샘주방       한샘             주방
# 81525            270                     270
# 81526    빈폴남성 반팔 티셔츠             빈폴남성 반팔 티셔츠
# 81528         MIUMIU                  MIUMIU
# 81529        세라 크로스백       세라           크로스백                             크로스백
# 81530        지지피엑스바지    지지피엑스             바지
# 81531            털모자                     털모자                    모자
# 81532        키플링 시티팩      키플링            시티팩
# 81533            모델로                     모델로
# 81534        이오시카제모기     이오시카            제모기                              제모기
# 81535       레스포색 토트백     레스포색            토트백
# 81536           프라이멀                    프라이멀
# 81537       FCMM 후리스                FCMM 후리스
#
# [76010 rows x 6 columns]

# %% [markdown]
# ### 2차 분류: "여성", "남성", "아동" 관련 단어 분리

# %%
for clac_nm in (CLAC2_unique):
  if "여성" in clac_nm or "남성" in clac_nm or "유아" in clac_nm or "남아" in clac_nm or "여아" in clac_nm:
    print(clac_nm)
# '여성', '남성', '유아', '남아', '여아'로 분류되어있는 CLAC names
# Out:
# 여아의류아우터
# 유아의류상의
# 남성스포츠화
# 유아스킨
# 남아완구
# 여아완구
# 남성의류하의
# 유아동가구
# 유아발육용품
# 남성골프의류
# 여성위생용품
# 여성가방
# 여성의류하의
# 유아의류전신
# 유아동속옷
# 여아의류상의
# 여성속옷
# 남아의류상의
# 여성의류아우터
# 유아동일반스포츠의류
# 유아동양말류
# 남성가방
# 유아동화
# 여성지갑
# 남아의류세트
# 유아의류아우터
# 여성골프의류
# 남성속옷
# 남성양말류
# 남성의류세트
# 유아의류하의
# 남성의류아우터
# 유아위생용품
# 여성양말류
# 여성일반스포츠의류
# 유아동스포츠화
# 남성의류상의
# 남성일반스포츠의류
# 유아안전용품
# 남성케어
# 남아의류하의
# 유아동침구
# 여성스포츠화
# 남성화
# 여아의류하의
# 여성화
# 남성지갑
# 여성의류상의
# 여성의류전신
# 여성등산
# 남성등산

# %%
# 1차 분류에서 분류되지 않은 것 중 '여성', '남성', '아동', '여아', '남아' 분리

mysearch1_3 = mysearch1_2[mysearch1_2["myCLAC1_NM"]==""][mysearch1_2["myCLAC2_NM"]==""][mysearch1_2["myCLAC3_NM"]==""][["KWD", "myBRD", "myKWD", 'myCLAC1_NM', 'myCLAC2_NM', 'myCLAC3_NM']]

myGROUP, myKWD = [], []
for kwd in mysearch1_3["myKWD"]:
  if "여성" in kwd or "여자" in kwd:
    myKWD.append(kwd.replace("여성", "").replace("여자", "").strip())
    myGROUP.append("여성")
  elif "남성" in kwd or "남자" in kwd:
    myKWD.append(kwd.replace("남성", "").replace("남자", "").strip())
    myGROUP.append("남성")
  elif "아동" in kwd or "유아" in kwd or "키즈" in kwd:
    myKWD.append(kwd.replace("아동", "").replace("유아", "").replace("키즈", "").strip())
    myGROUP.append("아동")
  elif "남아" in kwd:
    myKWD.append(kwd.replace("남아", "").strip())
    myGROUP.append("남아")
  elif "여아" in kwd:
    myKWD.append(kwd.replace("여아", "").strip())
    myGROUP.append("여아")
  else:
    myKWD.append(kwd)
    myGROUP.append("")
    
mysearch1_3["myGROUP"], mysearch1_3["myKWD"] = myGROUP, myKWD
mysearch1_3 = mysearch1_3[["KWD", "myBRD", "myGROUP", "myKWD", 'myCLAC1_NM', 'myCLAC2_NM', 'myCLAC3_NM']]
mysearch1_3
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                  KWD    myBRD myGROUP          myKWD myCLAC1_NM myCLAC2_NM  \
# 2                배불리                             배불리
# 3               유리꽃병                            유리꽃병
# 6           타미힐피거 카라    타미힐피거                     카라
# 7        아디다스 운동복 여성     아디다스      여성            운동복
# 8             튜닉블라우스                          튜닉블라우스
# 9              탑걸 자켓       탑걸                     자켓
# 10         아레나 반신 여성      아레나      여성             반신
# 11         M71MQ563Z                       M71MQ563Z
# 12              면 잠옷                            면 잠옷
# 13             인디안자켓      인디안                     자켓
# 16            남자 넥타이               남성            넥타이
# 17           여자 카드지갑               여성           카드지갑
# 21            르카프티셔츠                          르카프티셔츠
# 22                일본                              일본
# 24               수면팩                             수면팩
# 26           나이키 270      나이키                    270
# 28              룻데닷컴                            룻데닷컴
# 29         썰스데이 아일랜드                       썰스데이 아일랜드
# 30            롱트렌치코트                          롱트렌치코트
# 32               점퍼루                             점퍼루
# 34                치실                              치실
# 35               빈폴맨       빈폴                      맨
# 40                 팥                               팥
# 42             키즈상하복               아동            상하복
# 44          아동래쉬가드하의               아동         래쉬가드하의
# 45          에잇세컨즈 셔츠    에잇세컨즈                     셔츠
# 46           메트로시티샌들    메트로시티                     샌들
# 49         버버리 하우스체크      버버리                  하우스체크
# 51       크리스크리스티 반바지  크리스크리스티                    반바지
# 52           피그먼트 패드     피그먼트                     패드
# ...              ...      ...     ...            ...        ...        ...
# 81497            쟈스민                             쟈스민
# 81498        테팔스팀다리미       테팔                  스팀다리미
# 81499         숨 클렌징폼                          숨 클렌징폼
# 81500       남성 쿨 티셔츠               남성          쿨 티셔츠
# 81501         코치 스웨거       코치                    스웨거
# 81503         배럴드라이백       배럴                   드라이백
# 81504         마혼방 자켓                          마혼방 자켓
# 81505      에잇세컨즈블라우스    에잇세컨즈                   블라우스
# 81507         초고속블렌더                          초고속블렌더
# 81508        버켄스탁밀라노     버켄스탁                    밀라노
# 81510       아레나 미러수경      아레나                   미러수경
# 81511          팬티 세트                           팬티 세트
# 81515            메트로                             메트로
# 81517    갤럭시노트8 강화유리                     갤럭시노트8 강화유리
# 81518      HSSH7C708                       HSSH7C708
# 81519        크록스아동장화      크록스      아동             장화
# 81520         르꼬끄골프백    르꼬끄골프                      백
# 81521  CRP-FHR0610FD                   CRP-FHR0610FD
# 81522            쓰리심                             쓰리심
# 81523      여성 로퍼 3CM               여성         로퍼 3CM
# 81524           한샘주방       한샘                     주방
# 81525            270                             270
# 81526    빈폴남성 반팔 티셔츠               남성      빈폴 반팔 티셔츠
# 81528         MIUMIU                          MIUMIU
# 81530        지지피엑스바지    지지피엑스                     바지
# 81532        키플링 시티팩      키플링                    시티팩
# 81533            모델로                             모델로
# 81535       레스포색 토트백     레스포색                    토트백
# 81536           프라이멀                            프라이멀
# 81537       FCMM 후리스                        FCMM 후리스
#
#       myCLAC3_NM
# 2
# 3
# 6
# 7
# 8
# 9
# 10
# 11
# 12
# 13
# 16
# 17
# 21
# 22
# 24
# 26
# 28
# 29
# 30
# 32
# 34
# 35
# 40
# 42
# 44
# 45
# 46
# 49
# 51
# 52
# ...          ...
# 81497
# 81498
# 81499
# 81500
# 81501
# 81503
# 81504
# 81505
# 81507
# 81508
# 81510
# 81511
# 81515
# 81517
# 81518
# 81519
# 81520
# 81521
# 81522
# 81523
# 81524
# 81525
# 81526
# 81528
# 81530
# 81532
# 81533
# 81535
# 81536
# 81537
#
# [53327 rows x 7 columns]

# %%
# 분류명에서 '여성', '남성', '아동', '여아', '남아' 분리

CLAC1_unique2, CLAC2_unique2, CLAC3_unique2 = [], [], []

for clac in CLAC1_unique:
  if "여성" in clac or "남성" in clac or "유아동" in clac:
    CLAC1_unique2.append(clac.replace("여성", "").replace("남성", "").replace("유아동", ""))
  else: CLAC1_unique2.append(clac)

for clac in CLAC2_unique:
  if "여성" in clac or "남성" in clac or "유아" in clac or "여아" in clac or "남아" in clac:
    CLAC2_unique2.append(clac.replace("여성", "").replace("남성", "").replace("유아동", "").replace("유아", "").replace("여아", "").replace("남아", ""))
  else: CLAC2_unique2.append(clac)
    
for clac in CLAC3_unique:
  if "여성" in clac or "남성" in clac or "유아" in clac or "아동" in clac or "여아" in clac or "남아" in clac:
    CLAC3_unique2.append(clac.replace("여성", "").replace("남성", "").replace("유아동", "").replace("유아용", "").replace("영유아", "").replace("유아", "").replace("아동용", "").replace("아동", "").replace("여아", "").replace("남아", ""))
  else: CLAC3_unique2.append(clac)

CLAC1_unique2 = list(set(CLAC1_unique2))
CLAC2_unique2 = list(set(CLAC2_unique2))
CLAC3_unique2 = list(set(CLAC3_unique2))

# %%
for (i, clac) in enumerate(CLAC2_unique2):
  if clac == "화": CLAC2_unique2[i] = "신발"

# %%
### 2차 분류

myCLAC1, myCLAC2, myCLAC3 = [], [], []

for kwd in mysearch1_3["myKWD"]:
  c1, c2, c3 = "", "", ""
  
  if kwd in CLAC2_unique2: c2 = kwd
  elif kwd in CLAC3_unique2: c3 = kwd
  elif kwd in CLAC1_unique2: c1 = kwd

  else:
    for clac2 in CLAC2_unique2:
      if clac2 in kwd: c2 = clac2
      
    if c1 == "" and c2 == "" and c3 == "":
      for clac3 in CLAC3_unique2:
        if clac3 in kwd and len(clac3) > 1: c3 = clac3
      
      if c3 == "":
        for clac1 in CLAC1_unique2:
          if clac1 in kwd: c1 = clac1
            
  myCLAC1.append(c1)
  myCLAC2.append(c2)
  myCLAC3.append(c3)

# %%
mysearch1_4 = pd.DataFrame({'KWD':mysearch1_3["KWD"], 'myBRD':mysearch1_3["myBRD"], 'myGROUP':mysearch1_3["myGROUP"],
                            'myKWD':mysearch1_3["myKWD"], 'myCLAC1_NM':myCLAC1, 'myCLAC2_NM':myCLAC2, 'myCLAC3_NM':myCLAC3})
mysearch1_4 = mysearch1_4[['KWD', 'myBRD', 'myGROUP', 'myKWD', 'myCLAC1_NM', 'myCLAC2_NM', 'myCLAC3_NM']]
mysearch1_4
# Out:
#                  KWD    myBRD myGROUP          myKWD myCLAC1_NM myCLAC2_NM  \
# 2                배불리                             배불리
# 3               유리꽃병                            유리꽃병
# 6           타미힐피거 카라    타미힐피거                     카라
# 7        아디다스 운동복 여성     아디다스      여성            운동복
# 8             튜닉블라우스                          튜닉블라우스
# 9              탑걸 자켓       탑걸                     자켓
# 10         아레나 반신 여성      아레나      여성             반신
# 11         M71MQ563Z                       M71MQ563Z
# 12              면 잠옷                            면 잠옷
# 13             인디안자켓      인디안                     자켓
# 16            남자 넥타이               남성            넥타이
# 17           여자 카드지갑               여성           카드지갑                    지갑
# 21            르카프티셔츠                          르카프티셔츠
# 22                일본                              일본
# 24               수면팩                             수면팩
# 26           나이키 270      나이키                    270
# 28              룻데닷컴                            룻데닷컴
# 29         썰스데이 아일랜드                       썰스데이 아일랜드
# 30            롱트렌치코트                          롱트렌치코트
# 32               점퍼루                             점퍼루
# 34                치실                              치실
# 35               빈폴맨       빈폴                      맨
# 40                 팥                               팥
# 42             키즈상하복               아동            상하복
# 44          아동래쉬가드하의               아동         래쉬가드하의
# 45          에잇세컨즈 셔츠    에잇세컨즈                     셔츠
# 46           메트로시티샌들    메트로시티                     샌들
# 49         버버리 하우스체크      버버리                  하우스체크
# 51       크리스크리스티 반바지  크리스크리스티                    반바지
# 52           피그먼트 패드     피그먼트                     패드
# ...              ...      ...     ...            ...        ...        ...
# 81497            쟈스민                             쟈스민
# 81498        테팔스팀다리미       테팔                  스팀다리미
# 81499         숨 클렌징폼                          숨 클렌징폼
# 81500       남성 쿨 티셔츠               남성          쿨 티셔츠
# 81501         코치 스웨거       코치                    스웨거
# 81503         배럴드라이백       배럴                   드라이백
# 81504         마혼방 자켓                          마혼방 자켓
# 81505      에잇세컨즈블라우스    에잇세컨즈                   블라우스
# 81507         초고속블렌더                          초고속블렌더
# 81508        버켄스탁밀라노     버켄스탁                    밀라노
# 81510       아레나 미러수경      아레나                   미러수경
# 81511          팬티 세트                           팬티 세트
# 81515            메트로                             메트로
# 81517    갤럭시노트8 강화유리                     갤럭시노트8 강화유리
# 81518      HSSH7C708                       HSSH7C708
# 81519        크록스아동장화      크록스      아동             장화
# 81520         르꼬끄골프백    르꼬끄골프                      백
# 81521  CRP-FHR0610FD                   CRP-FHR0610FD
# 81522            쓰리심                             쓰리심
# 81523      여성 로퍼 3CM               여성         로퍼 3CM
# 81524           한샘주방       한샘                     주방
# 81525            270                             270
# 81526    빈폴남성 반팔 티셔츠               남성      빈폴 반팔 티셔츠
# 81528         MIUMIU                          MIUMIU
# 81530        지지피엑스바지    지지피엑스                     바지
# 81532        키플링 시티팩      키플링                    시티팩
# 81533            모델로                             모델로
# 81535       레스포색 토트백     레스포색                    토트백
# 81536           프라이멀                            프라이멀
# 81537       FCMM 후리스                        FCMM 후리스
#
#       myCLAC3_NM
# 2
# 3
# 6
# 7
# 8           블라우스
# 9
# 10
# 11
# 12            잠옷
# 13
# 16
# 17
# 21            셔츠
# 22
# 24
# 26
# 28
# 29
# 30            코트
# 32            점퍼
# 34
# 35
# 40
# 42
# 44
# 45            셔츠
# 46            샌들
# 49
# 51            바지
# 52            패드
# ...          ...
# 81497
# 81498
# 81499
# 81500         셔츠
# 81501
# 81503
# 81504
# 81505       블라우스
# 81507
# 81508
# 81510
# 81511         팬티
# 81515
# 81517
# 81518
# 81519
# 81520
# 81521
# 81522
# 81523         로퍼
# 81524
# 81525
# 81526         셔츠
# 81528
# 81530         바지
# 81532
# 81533
# 81535        토트백
# 81536
# 81537
#
# [53327 rows x 7 columns]

# %%
mysearch1_2.to_csv("gdrive/My Drive/mysearch1_2.csv", encoding="cp949")
mysearch1_4.to_csv("gdrive/My Drive/mysearch1_4.csv", encoding="cp949")
